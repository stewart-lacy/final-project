# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.stats import binned_statistic_2d
from matplotlib.patches import Circle, Rectangle, Arc
import seaborn as sns
from bokeh.plotting import figure, ColumnDataSource
from bokeh.models import HoverTool
from math import pi

# %%
chicago = "csv/shot log CHI.csv"

chicago_df = pd.read_csv(chicago)
chicago_df
# Out:
#      self previous shot player position home game  location x  \
# 0                   NaN              SG       Yes       239.0
# 1                SCORED              PF       Yes        64.0
# 2                MISSED              PG       Yes        67.0
# 3                MISSED               C       Yes       102.0
# 4                MISSED              SG       Yes       241.0
# ...                 ...             ...       ...         ...
# 7134             SCORED               G       Yes       640.0
# 7135             SCORED               G       Yes       675.0
# 7136             MISSED              SG       Yes       848.0
# 7137             SCORED              PF       Yes       691.0
# 7138             SCORED               G       Yes       661.0
#
#      opponent previous shot home team      shot type  points away team  \
# 0                       NaN       CHI      Jump Shot       2       BOS
# 1                    MISSED       CHI      Hook Shot       2       BOS
# 2                    MISSED       CHI  Driving Layup       2       BOS
# 3                    MISSED       CHI      Hook Shot       2       BOS
# 4                    SCORED       CHI      Jump Shot       2       BOS
# ...                     ...       ...            ...     ...       ...
# 7134                 MISSED       CHI      Jump Shot       3       BRO
# 7135                 MISSED       CHI      Jump Shot       3       BRO
# 7136                 SCORED       CHI      Jump Shot       2       BRO
# 7137                 MISSED       CHI      Jump Shot       3       BRO
# 7138                 MISSED       CHI      Jump Shot       3       BRO
#
#       location y   time        date      shoot player  time from last shot  \
# 0          169.0   0:17  2016-10-27       Dwyane Wade                  NaN
# 1          215.0   1:08  2016-10-27        Taj Gibson                 51.0
# 2          259.0   1:15  2016-10-27       Rajon Rondo                  7.0
# 3          243.0   1:27  2016-10-27       Robin Lopez                 12.0
# 4          210.0   1:57  2016-10-27       Dwyane Wade                 30.0
# ...          ...    ...         ...               ...                  ...
# 7134       212.0   9:42  2017-04-12  Denzel Valentine                 27.0
# 7135       113.0  10:13  2017-04-12  Denzel Valentine                 31.0
# 7136       112.0  10:39  2017-04-12    Anthony Morrow                 26.0
# 7137        99.0  11:10  2017-04-12      Bobby Portis                 31.0
# 7138       372.0  11:32  2017-04-12  Denzel Valentine                 22.0
#
#       quarter current shot outcome
# 0           1               SCORED
# 1           1               MISSED
# 2           1               MISSED
# 3           1               MISSED
# 4           1               MISSED
# ...       ...                  ...
# 7134        4               SCORED
# 7135        4               MISSED
# 7136        4               SCORED
# 7137        4               SCORED
# 7138        4               MISSED
#
# [7139 rows x 16 columns]

# %%
shot_df = chicago_df.rename(columns={"location x": "LOC_Y", "location y": "LOC_X", "player position": "position", "shoot player": "shooter", "current shot outcome": "current_shot_outcome"})
shot_df
# Out:
#      self previous shot position home game  LOC_Y opponent previous shot  \
# 0                   NaN       SG       Yes  239.0                    NaN
# 1                SCORED       PF       Yes   64.0                 MISSED
# 2                MISSED       PG       Yes   67.0                 MISSED
# 3                MISSED        C       Yes  102.0                 MISSED
# 4                MISSED       SG       Yes  241.0                 SCORED
# ...                 ...      ...       ...    ...                    ...
# 7134             SCORED        G       Yes  640.0                 MISSED
# 7135             SCORED        G       Yes  675.0                 MISSED
# 7136             MISSED       SG       Yes  848.0                 SCORED
# 7137             SCORED       PF       Yes  691.0                 MISSED
# 7138             SCORED        G       Yes  661.0                 MISSED
#
#      home team      shot type  points away team  LOC_X   time        date  \
# 0          CHI      Jump Shot       2       BOS  169.0   0:17  2016-10-27
# 1          CHI      Hook Shot       2       BOS  215.0   1:08  2016-10-27
# 2          CHI  Driving Layup       2       BOS  259.0   1:15  2016-10-27
# 3          CHI      Hook Shot       2       BOS  243.0   1:27  2016-10-27
# 4          CHI      Jump Shot       2       BOS  210.0   1:57  2016-10-27
# ...        ...            ...     ...       ...    ...    ...         ...
# 7134       CHI      Jump Shot       3       BRO  212.0   9:42  2017-04-12
# 7135       CHI      Jump Shot       3       BRO  113.0  10:13  2017-04-12
# 7136       CHI      Jump Shot       2       BRO  112.0  10:39  2017-04-12
# 7137       CHI      Jump Shot       3       BRO   99.0  11:10  2017-04-12
# 7138       CHI      Jump Shot       3       BRO  372.0  11:32  2017-04-12
#
#                shooter  time from last shot  quarter current_shot_outcome
# 0          Dwyane Wade                  NaN        1               SCORED
# 1           Taj Gibson                 51.0        1               MISSED
# 2          Rajon Rondo                  7.0        1               MISSED
# 3          Robin Lopez                 12.0        1               MISSED
# 4          Dwyane Wade                 30.0        1               MISSED
# ...                ...                  ...      ...                  ...
# 7134  Denzel Valentine                 27.0        4               SCORED
# 7135  Denzel Valentine                 31.0        4               MISSED
# 7136    Anthony Morrow                 26.0        4               SCORED
# 7137      Bobby Portis                 31.0        4               SCORED
# 7138  Denzel Valentine                 22.0        4               MISSED
#
# [7139 rows x 16 columns]

# %%
farCourt = shot_df[ shot_df['LOC_Y'] > 470 ].index
# Delete these row indexes from dataFrame
shot_df.drop(farCourt , inplace=True)

# %%
shot_df
# Out:
#      self previous shot position home game  LOC_Y opponent previous shot  \
# 0                   NaN       SG       Yes  239.0                    NaN
# 1                SCORED       PF       Yes   64.0                 MISSED
# 2                MISSED       PG       Yes   67.0                 MISSED
# 3                MISSED        C       Yes  102.0                 MISSED
# 4                MISSED       SG       Yes  241.0                 SCORED
# ...                 ...      ...       ...    ...                    ...
# 7084             MISSED       PF       Yes  288.0                 SCORED
# 7085             SCORED       PF       Yes  275.0                 SCORED
# 7086             MISSED       PG       Yes  102.0                 MISSED
# 7087            BLOCKED       PF       Yes  259.0                 SCORED
# 7088             MISSED        C       Yes   79.0                 SCORED
#
#      home team      shot type  points away team  LOC_X   time        date  \
# 0          CHI      Jump Shot       2       BOS  169.0   0:17  2016-10-27
# 1          CHI      Hook Shot       2       BOS  215.0   1:08  2016-10-27
# 2          CHI  Driving Layup       2       BOS  259.0   1:15  2016-10-27
# 3          CHI      Hook Shot       2       BOS  243.0   1:27  2016-10-27
# 4          CHI      Jump Shot       2       BOS  210.0   1:57  2016-10-27
# ...        ...            ...     ...       ...    ...    ...         ...
# 7084       CHI      Jump Shot       3       BRO  319.0   9:34  2017-04-12
# 7085       CHI      Jump Shot       3       BRO  339.0  10:02  2017-04-12
# 7086       CHI      Jump Shot       2       BRO  311.0  10:31  2017-04-12
# 7087       CHI      Jump Shot       3       BRO  408.0  10:47  2017-04-12
# 7088       CHI      Hook Shot       2       BRO  254.0  11:25  2017-04-12
#
#              shooter  time from last shot  quarter current_shot_outcome
# 0        Dwyane Wade                  NaN        1               SCORED
# 1         Taj Gibson                 51.0        1               MISSED
# 2        Rajon Rondo                  7.0        1               MISSED
# 3        Robin Lopez                 12.0        1               MISSED
# 4        Dwyane Wade                 30.0        1               MISSED
# ...              ...                  ...      ...                  ...
# 7084  Nikola Mirotic                 42.0        2               SCORED
# 7085  Nikola Mirotic                 28.0        2               MISSED
# 7086     Rajon Rondo                 29.0        2              BLOCKED
# 7087  Nikola Mirotic                 16.0        2               MISSED
# 7088     Robin Lopez                 38.0        2               MISSED
#
# [3658 rows x 16 columns]

# %%
chicago = "csv/shot log CHI2.csv"
chicago2_df = pd.read_csv(chicago)
chicago2_df
# Out:
#      self previous shot player position home game  location x  \
# 0                   NaN              SG       Yes       239.0
# 1                SCORED              PF       Yes        64.0
# 2                MISSED              PG       Yes        67.0
# 3                MISSED               C       Yes       102.0
# 4                MISSED              SG       Yes       241.0
# ...                 ...             ...       ...         ...
# 7134             SCORED               G       Yes       640.0
# 7135             SCORED               G       Yes       675.0
# 7136             MISSED              SG       Yes       848.0
# 7137             SCORED              PF       Yes       691.0
# 7138             SCORED               G       Yes       661.0
#
#      opponent previous shot home team      shot type  points away team  \
# 0                       NaN       CHI      Jump Shot       2       BOS
# 1                    MISSED       CHI      Hook Shot       2       BOS
# 2                    MISSED       CHI  Driving Layup       2       BOS
# 3                    MISSED       CHI      Hook Shot       2       BOS
# 4                    SCORED       CHI      Jump Shot       2       BOS
# ...                     ...       ...            ...     ...       ...
# 7134                 MISSED       CHI      Jump Shot       3       BRO
# 7135                 MISSED       CHI      Jump Shot       3       BRO
# 7136                 SCORED       CHI      Jump Shot       2       BRO
# 7137                 MISSED       CHI      Jump Shot       3       BRO
# 7138                 MISSED       CHI      Jump Shot       3       BRO
#
#       location y   time        date      shoot player  time from last shot  \
# 0          169.0   0:17  2016-10-27       Dwyane Wade                  NaN
# 1          215.0   1:08  2016-10-27        Taj Gibson                 51.0
# 2          259.0   1:15  2016-10-27       Rajon Rondo                  7.0
# 3          243.0   1:27  2016-10-27       Robin Lopez                 12.0
# 4          210.0   1:57  2016-10-27       Dwyane Wade                 30.0
# ...          ...    ...         ...               ...                  ...
# 7134       212.0   9:42  2017-04-12  Denzel Valentine                 27.0
# 7135       113.0  10:13  2017-04-12  Denzel Valentine                 31.0
# 7136       112.0  10:39  2017-04-12    Anthony Morrow                 26.0
# 7137        99.0  11:10  2017-04-12      Bobby Portis                 31.0
# 7138       372.0  11:32  2017-04-12  Denzel Valentine                 22.0
#
#       quarter current shot outcome
# 0           1               SCORED
# 1           1               MISSED
# 2           1               MISSED
# 3           1               MISSED
# 4           1               MISSED
# ...       ...                  ...
# 7134        4               SCORED
# 7135        4               MISSED
# 7136        4               SCORED
# 7137        4               SCORED
# 7138        4               MISSED
#
# [7139 rows x 16 columns]

# %%
far_df = chicago2_df.rename(columns={"location x": "LOC_X", "location y": "LOC_Y", "player position": "position", "shoot player": "shooter"})
far_df
# Out:
#      self previous shot position home game  LOC_X opponent previous shot  \
# 0                   NaN       SG       Yes  239.0                    NaN
# 1                SCORED       PF       Yes   64.0                 MISSED
# 2                MISSED       PG       Yes   67.0                 MISSED
# 3                MISSED        C       Yes  102.0                 MISSED
# 4                MISSED       SG       Yes  241.0                 SCORED
# ...                 ...      ...       ...    ...                    ...
# 7134             SCORED        G       Yes  640.0                 MISSED
# 7135             SCORED        G       Yes  675.0                 MISSED
# 7136             MISSED       SG       Yes  848.0                 SCORED
# 7137             SCORED       PF       Yes  691.0                 MISSED
# 7138             SCORED        G       Yes  661.0                 MISSED
#
#      home team      shot type  points away team  LOC_Y   time        date  \
# 0          CHI      Jump Shot       2       BOS  169.0   0:17  2016-10-27
# 1          CHI      Hook Shot       2       BOS  215.0   1:08  2016-10-27
# 2          CHI  Driving Layup       2       BOS  259.0   1:15  2016-10-27
# 3          CHI      Hook Shot       2       BOS  243.0   1:27  2016-10-27
# 4          CHI      Jump Shot       2       BOS  210.0   1:57  2016-10-27
# ...        ...            ...     ...       ...    ...    ...         ...
# 7134       CHI      Jump Shot       3       BRO  212.0   9:42  2017-04-12
# 7135       CHI      Jump Shot       3       BRO  113.0  10:13  2017-04-12
# 7136       CHI      Jump Shot       2       BRO  112.0  10:39  2017-04-12
# 7137       CHI      Jump Shot       3       BRO   99.0  11:10  2017-04-12
# 7138       CHI      Jump Shot       3       BRO  372.0  11:32  2017-04-12
#
#                shooter  time from last shot  quarter current shot outcome
# 0          Dwyane Wade                  NaN        1               SCORED
# 1           Taj Gibson                 51.0        1               MISSED
# 2          Rajon Rondo                  7.0        1               MISSED
# 3          Robin Lopez                 12.0        1               MISSED
# 4          Dwyane Wade                 30.0        1               MISSED
# ...                ...                  ...      ...                  ...
# 7134  Denzel Valentine                 27.0        4               SCORED
# 7135  Denzel Valentine                 31.0        4               MISSED
# 7136    Anthony Morrow                 26.0        4               SCORED
# 7137      Bobby Portis                 31.0        4               SCORED
# 7138  Denzel Valentine                 22.0        4               MISSED
#
# [7139 rows x 16 columns]

# %%
# Get names of indexes for which column Age has value 30
nearCourt = far_df[ far_df['LOC_X'] < 470 ].index
# Delete these row indexes from dataFrame
far_df.drop(nearCourt , inplace=True)

# %%
far_df
# Out:
#      self previous shot position home game  LOC_X opponent previous shot  \
# 47               SCORED       PF       Yes  863.0                 SCORED
# 48               MISSED        C       Yes  887.0                 SCORED
# 49               SCORED       PG       Yes  886.0                 SCORED
# 50               MISSED       PF       Yes  706.0                 SCORED
# 51               SCORED       SG       Yes  890.0                 MISSED
# ...                 ...      ...       ...    ...                    ...
# 7134             SCORED        G       Yes  640.0                 MISSED
# 7135             SCORED        G       Yes  675.0                 MISSED
# 7136             MISSED       SG       Yes  848.0                 SCORED
# 7137             SCORED       PF       Yes  691.0                 MISSED
# 7138             SCORED        G       Yes  661.0                 MISSED
#
#      home team         shot type  points away team  LOC_Y   time        date  \
# 47         CHI     Driving Layup       2       BOS  251.0   0:33  2016-10-27
# 48         CHI    Tip Layup Shot       2       BOS  241.0   0:35  2016-10-27
# 49         CHI  Pullup Jump Shot       2       BOS  413.0   1:22  2016-10-27
# 50         CHI         Jump Shot       2       BOS  174.0   1:42  2016-10-27
# 51         CHI         Jump Shot       2       BOS  433.0   2:05  2016-10-27
# ...        ...               ...     ...       ...    ...    ...         ...
# 7134       CHI         Jump Shot       3       BRO  212.0   9:42  2017-04-12
# 7135       CHI         Jump Shot       3       BRO  113.0  10:13  2017-04-12
# 7136       CHI         Jump Shot       2       BRO  112.0  10:39  2017-04-12
# 7137       CHI         Jump Shot       3       BRO   99.0  11:10  2017-04-12
# 7138       CHI         Jump Shot       3       BRO  372.0  11:32  2017-04-12
#
#                shooter  time from last shot  quarter current shot outcome
# 47          Taj Gibson                  NaN        3               MISSED
# 48         Robin Lopez                  2.0        3               SCORED
# 49         Rajon Rondo                 47.0        3               MISSED
# 50          Taj Gibson                 20.0        3               SCORED
# 51         Dwyane Wade                 23.0        3               MISSED
# ...                ...                  ...      ...                  ...
# 7134  Denzel Valentine                 27.0        4               SCORED
# 7135  Denzel Valentine                 31.0        4               MISSED
# 7136    Anthony Morrow                 26.0        4               SCORED
# 7137      Bobby Portis                 31.0        4               SCORED
# 7138  Denzel Valentine                 22.0        4               MISSED
#
# [3484 rows x 16 columns]

# %%
far_df['LOC_X2'] = far_df.apply(lambda row: (row.LOC_Y - 500) * (-1), axis = 1) 

far_df
# Out:
#      self previous shot position home game  LOC_X opponent previous shot  \
# 47               SCORED       PF       Yes  863.0                 SCORED
# 48               MISSED        C       Yes  887.0                 SCORED
# 49               SCORED       PG       Yes  886.0                 SCORED
# 50               MISSED       PF       Yes  706.0                 SCORED
# 51               SCORED       SG       Yes  890.0                 MISSED
# ...                 ...      ...       ...    ...                    ...
# 7134             SCORED        G       Yes  640.0                 MISSED
# 7135             SCORED        G       Yes  675.0                 MISSED
# 7136             MISSED       SG       Yes  848.0                 SCORED
# 7137             SCORED       PF       Yes  691.0                 MISSED
# 7138             SCORED        G       Yes  661.0                 MISSED
#
#      home team         shot type  points away team  LOC_Y   time        date  \
# 47         CHI     Driving Layup       2       BOS  251.0   0:33  2016-10-27
# 48         CHI    Tip Layup Shot       2       BOS  241.0   0:35  2016-10-27
# 49         CHI  Pullup Jump Shot       2       BOS  413.0   1:22  2016-10-27
# 50         CHI         Jump Shot       2       BOS  174.0   1:42  2016-10-27
# 51         CHI         Jump Shot       2       BOS  433.0   2:05  2016-10-27
# ...        ...               ...     ...       ...    ...    ...         ...
# 7134       CHI         Jump Shot       3       BRO  212.0   9:42  2017-04-12
# 7135       CHI         Jump Shot       3       BRO  113.0  10:13  2017-04-12
# 7136       CHI         Jump Shot       2       BRO  112.0  10:39  2017-04-12
# 7137       CHI         Jump Shot       3       BRO   99.0  11:10  2017-04-12
# 7138       CHI         Jump Shot       3       BRO  372.0  11:32  2017-04-12
#
#                shooter  time from last shot  quarter current shot outcome  \
# 47          Taj Gibson                  NaN        3               MISSED
# 48         Robin Lopez                  2.0        3               SCORED
# 49         Rajon Rondo                 47.0        3               MISSED
# 50          Taj Gibson                 20.0        3               SCORED
# 51         Dwyane Wade                 23.0        3               MISSED
# ...                ...                  ...      ...                  ...
# 7134  Denzel Valentine                 27.0        4               SCORED
# 7135  Denzel Valentine                 31.0        4               MISSED
# 7136    Anthony Morrow                 26.0        4               SCORED
# 7137      Bobby Portis                 31.0        4               SCORED
# 7138  Denzel Valentine                 22.0        4               MISSED
#
#       LOC_X2
# 47     249.0
# 48     259.0
# 49      87.0
# 50     326.0
# 51      67.0
# ...      ...
# 7134   288.0
# 7135   387.0
# 7136   388.0
# 7137   401.0
# 7138   128.0
#
# [3484 rows x 17 columns]

# %%
far_df['distance_from_half'] = far_df.apply(lambda row: (row.LOC_X - 470) * 2, axis = 1) 
far_df
# Out:
#      self previous shot position home game  LOC_X opponent previous shot  \
# 47               SCORED       PF       Yes  863.0                 SCORED
# 48               MISSED        C       Yes  887.0                 SCORED
# 49               SCORED       PG       Yes  886.0                 SCORED
# 50               MISSED       PF       Yes  706.0                 SCORED
# 51               SCORED       SG       Yes  890.0                 MISSED
# ...                 ...      ...       ...    ...                    ...
# 7134             SCORED        G       Yes  640.0                 MISSED
# 7135             SCORED        G       Yes  675.0                 MISSED
# 7136             MISSED       SG       Yes  848.0                 SCORED
# 7137             SCORED       PF       Yes  691.0                 MISSED
# 7138             SCORED        G       Yes  661.0                 MISSED
#
#      home team         shot type  points away team  LOC_Y   time        date  \
# 47         CHI     Driving Layup       2       BOS  251.0   0:33  2016-10-27
# 48         CHI    Tip Layup Shot       2       BOS  241.0   0:35  2016-10-27
# 49         CHI  Pullup Jump Shot       2       BOS  413.0   1:22  2016-10-27
# 50         CHI         Jump Shot       2       BOS  174.0   1:42  2016-10-27
# 51         CHI         Jump Shot       2       BOS  433.0   2:05  2016-10-27
# ...        ...               ...     ...       ...    ...    ...         ...
# 7134       CHI         Jump Shot       3       BRO  212.0   9:42  2017-04-12
# 7135       CHI         Jump Shot       3       BRO  113.0  10:13  2017-04-12
# 7136       CHI         Jump Shot       2       BRO  112.0  10:39  2017-04-12
# 7137       CHI         Jump Shot       3       BRO   99.0  11:10  2017-04-12
# 7138       CHI         Jump Shot       3       BRO  372.0  11:32  2017-04-12
#
#                shooter  time from last shot  quarter current shot outcome  \
# 47          Taj Gibson                  NaN        3               MISSED
# 48         Robin Lopez                  2.0        3               SCORED
# 49         Rajon Rondo                 47.0        3               MISSED
# 50          Taj Gibson                 20.0        3               SCORED
# 51         Dwyane Wade                 23.0        3               MISSED
# ...                ...                  ...      ...                  ...
# 7134  Denzel Valentine                 27.0        4               SCORED
# 7135  Denzel Valentine                 31.0        4               MISSED
# 7136    Anthony Morrow                 26.0        4               SCORED
# 7137      Bobby Portis                 31.0        4               SCORED
# 7138  Denzel Valentine                 22.0        4               MISSED
#
#       LOC_X2  distance_from_half
# 47     249.0               786.0
# 48     259.0               834.0
# 49      87.0               832.0
# 50     326.0               472.0
# 51      67.0               840.0
# ...      ...                 ...
# 7134   288.0               340.0
# 7135   387.0               410.0
# 7136   388.0               756.0
# 7137   401.0               442.0
# 7138   128.0               382.0
#
# [3484 rows x 18 columns]

# %%
far_df['LOC_Y2'] = far_df.LOC_X - far_df.distance_from_half
far_df
# Out:
#      self previous shot position home game  LOC_X opponent previous shot  \
# 47               SCORED       PF       Yes  863.0                 SCORED
# 48               MISSED        C       Yes  887.0                 SCORED
# 49               SCORED       PG       Yes  886.0                 SCORED
# 50               MISSED       PF       Yes  706.0                 SCORED
# 51               SCORED       SG       Yes  890.0                 MISSED
# ...                 ...      ...       ...    ...                    ...
# 7134             SCORED        G       Yes  640.0                 MISSED
# 7135             SCORED        G       Yes  675.0                 MISSED
# 7136             MISSED       SG       Yes  848.0                 SCORED
# 7137             SCORED       PF       Yes  691.0                 MISSED
# 7138             SCORED        G       Yes  661.0                 MISSED
#
#      home team         shot type  points away team  LOC_Y   time        date  \
# 47         CHI     Driving Layup       2       BOS  251.0   0:33  2016-10-27
# 48         CHI    Tip Layup Shot       2       BOS  241.0   0:35  2016-10-27
# 49         CHI  Pullup Jump Shot       2       BOS  413.0   1:22  2016-10-27
# 50         CHI         Jump Shot       2       BOS  174.0   1:42  2016-10-27
# 51         CHI         Jump Shot       2       BOS  433.0   2:05  2016-10-27
# ...        ...               ...     ...       ...    ...    ...         ...
# 7134       CHI         Jump Shot       3       BRO  212.0   9:42  2017-04-12
# 7135       CHI         Jump Shot       3       BRO  113.0  10:13  2017-04-12
# 7136       CHI         Jump Shot       2       BRO  112.0  10:39  2017-04-12
# 7137       CHI         Jump Shot       3       BRO   99.0  11:10  2017-04-12
# 7138       CHI         Jump Shot       3       BRO  372.0  11:32  2017-04-12
#
#                shooter  time from last shot  quarter current shot outcome  \
# 47          Taj Gibson                  NaN        3               MISSED
# 48         Robin Lopez                  2.0        3               SCORED
# 49         Rajon Rondo                 47.0        3               MISSED
# 50          Taj Gibson                 20.0        3               SCORED
# 51         Dwyane Wade                 23.0        3               MISSED
# ...                ...                  ...      ...                  ...
# 7134  Denzel Valentine                 27.0        4               SCORED
# 7135  Denzel Valentine                 31.0        4               MISSED
# 7136    Anthony Morrow                 26.0        4               SCORED
# 7137      Bobby Portis                 31.0        4               SCORED
# 7138  Denzel Valentine                 22.0        4               MISSED
#
#       LOC_X2  distance_from_half  LOC_Y2
# 47     249.0               786.0    77.0
# 48     259.0               834.0    53.0
# 49      87.0               832.0    54.0
# 50     326.0               472.0   234.0
# 51      67.0               840.0    50.0
# ...      ...                 ...     ...
# 7134   288.0               340.0   300.0
# 7135   387.0               410.0   265.0
# 7136   388.0               756.0    92.0
# 7137   401.0               442.0   249.0
# 7138   128.0               382.0   279.0
#
# [3484 rows x 19 columns]

# %%
new_far_df = far_df.drop(columns =['LOC_X', 'LOC_Y'])
new_far_df
# Out:
#      self previous shot position home game opponent previous shot home team  \
# 47               SCORED       PF       Yes                 SCORED       CHI
# 48               MISSED        C       Yes                 SCORED       CHI
# 49               SCORED       PG       Yes                 SCORED       CHI
# 50               MISSED       PF       Yes                 SCORED       CHI
# 51               SCORED       SG       Yes                 MISSED       CHI
# ...                 ...      ...       ...                    ...       ...
# 7134             SCORED        G       Yes                 MISSED       CHI
# 7135             SCORED        G       Yes                 MISSED       CHI
# 7136             MISSED       SG       Yes                 SCORED       CHI
# 7137             SCORED       PF       Yes                 MISSED       CHI
# 7138             SCORED        G       Yes                 MISSED       CHI
#
#              shot type  points away team   time        date           shooter  \
# 47       Driving Layup       2       BOS   0:33  2016-10-27        Taj Gibson
# 48      Tip Layup Shot       2       BOS   0:35  2016-10-27       Robin Lopez
# 49    Pullup Jump Shot       2       BOS   1:22  2016-10-27       Rajon Rondo
# 50           Jump Shot       2       BOS   1:42  2016-10-27        Taj Gibson
# 51           Jump Shot       2       BOS   2:05  2016-10-27       Dwyane Wade
# ...                ...     ...       ...    ...         ...               ...
# 7134         Jump Shot       3       BRO   9:42  2017-04-12  Denzel Valentine
# 7135         Jump Shot       3       BRO  10:13  2017-04-12  Denzel Valentine
# 7136         Jump Shot       2       BRO  10:39  2017-04-12    Anthony Morrow
# 7137         Jump Shot       3       BRO  11:10  2017-04-12      Bobby Portis
# 7138         Jump Shot       3       BRO  11:32  2017-04-12  Denzel Valentine
#
#       time from last shot  quarter current shot outcome  LOC_X2  \
# 47                    NaN        3               MISSED   249.0
# 48                    2.0        3               SCORED   259.0
# 49                   47.0        3               MISSED    87.0
# 50                   20.0        3               SCORED   326.0
# 51                   23.0        3               MISSED    67.0
# ...                   ...      ...                  ...     ...
# 7134                 27.0        4               SCORED   288.0
# 7135                 31.0        4               MISSED   387.0
# 7136                 26.0        4               SCORED   388.0
# 7137                 31.0        4               SCORED   401.0
# 7138                 22.0        4               MISSED   128.0
#
#       distance_from_half  LOC_Y2
# 47                 786.0    77.0
# 48                 834.0    53.0
# 49                 832.0    54.0
# 50                 472.0   234.0
# 51                 840.0    50.0
# ...                  ...     ...
# 7134               340.0   300.0
# 7135               410.0   265.0
# 7136               756.0    92.0
# 7137               442.0   249.0
# 7138               382.0   279.0
#
# [3484 rows x 17 columns]

# %%
halfcourt_df = new_far_df.rename(columns={"LOC_X2": "LOC_X", "LOC_Y2": "LOC_Y", "current shot outcome": "current_shot_outcome"})
halfcourt_df
# Out:
#      self previous shot position home game opponent previous shot home team  \
# 47               SCORED       PF       Yes                 SCORED       CHI
# 48               MISSED        C       Yes                 SCORED       CHI
# 49               SCORED       PG       Yes                 SCORED       CHI
# 50               MISSED       PF       Yes                 SCORED       CHI
# 51               SCORED       SG       Yes                 MISSED       CHI
# ...                 ...      ...       ...                    ...       ...
# 7134             SCORED        G       Yes                 MISSED       CHI
# 7135             SCORED        G       Yes                 MISSED       CHI
# 7136             MISSED       SG       Yes                 SCORED       CHI
# 7137             SCORED       PF       Yes                 MISSED       CHI
# 7138             SCORED        G       Yes                 MISSED       CHI
#
#              shot type  points away team   time        date           shooter  \
# 47       Driving Layup       2       BOS   0:33  2016-10-27        Taj Gibson
# 48      Tip Layup Shot       2       BOS   0:35  2016-10-27       Robin Lopez
# 49    Pullup Jump Shot       2       BOS   1:22  2016-10-27       Rajon Rondo
# 50           Jump Shot       2       BOS   1:42  2016-10-27        Taj Gibson
# 51           Jump Shot       2       BOS   2:05  2016-10-27       Dwyane Wade
# ...                ...     ...       ...    ...         ...               ...
# 7134         Jump Shot       3       BRO   9:42  2017-04-12  Denzel Valentine
# 7135         Jump Shot       3       BRO  10:13  2017-04-12  Denzel Valentine
# 7136         Jump Shot       2       BRO  10:39  2017-04-12    Anthony Morrow
# 7137         Jump Shot       3       BRO  11:10  2017-04-12      Bobby Portis
# 7138         Jump Shot       3       BRO  11:32  2017-04-12  Denzel Valentine
#
#       time from last shot  quarter current_shot_outcome  LOC_X  \
# 47                    NaN        3               MISSED  249.0
# 48                    2.0        3               SCORED  259.0
# 49                   47.0        3               MISSED   87.0
# 50                   20.0        3               SCORED  326.0
# 51                   23.0        3               MISSED   67.0
# ...                   ...      ...                  ...    ...
# 7134                 27.0        4               SCORED  288.0
# 7135                 31.0        4               MISSED  387.0
# 7136                 26.0        4               SCORED  388.0
# 7137                 31.0        4               SCORED  401.0
# 7138                 22.0        4               MISSED  128.0
#
#       distance_from_half  LOC_Y
# 47                 786.0   77.0
# 48                 834.0   53.0
# 49                 832.0   54.0
# 50                 472.0  234.0
# 51                 840.0   50.0
# ...                  ...    ...
# 7134               340.0  300.0
# 7135               410.0  265.0
# 7136               756.0   92.0
# 7137               442.0  249.0
# 7138               382.0  279.0
#
# [3484 rows x 17 columns]

# %%
full_df = shot_df.append(halfcourt_df, ignore_index=True)
full_df
# Out:
#      self previous shot position home game  LOC_Y opponent previous shot  \
# 0                   NaN       SG       Yes  239.0                    NaN
# 1                SCORED       PF       Yes   64.0                 MISSED
# 2                MISSED       PG       Yes   67.0                 MISSED
# 3                MISSED        C       Yes  102.0                 MISSED
# 4                MISSED       SG       Yes  241.0                 SCORED
# ...                 ...      ...       ...    ...                    ...
# 7137             SCORED        G       Yes  300.0                 MISSED
# 7138             SCORED        G       Yes  265.0                 MISSED
# 7139             MISSED       SG       Yes   92.0                 SCORED
# 7140             SCORED       PF       Yes  249.0                 MISSED
# 7141             SCORED        G       Yes  279.0                 MISSED
#
#      home team      shot type  points away team  LOC_X   time        date  \
# 0          CHI      Jump Shot       2       BOS  169.0   0:17  2016-10-27
# 1          CHI      Hook Shot       2       BOS  215.0   1:08  2016-10-27
# 2          CHI  Driving Layup       2       BOS  259.0   1:15  2016-10-27
# 3          CHI      Hook Shot       2       BOS  243.0   1:27  2016-10-27
# 4          CHI      Jump Shot       2       BOS  210.0   1:57  2016-10-27
# ...        ...            ...     ...       ...    ...    ...         ...
# 7137       CHI      Jump Shot       3       BRO  288.0   9:42  2017-04-12
# 7138       CHI      Jump Shot       3       BRO  387.0  10:13  2017-04-12
# 7139       CHI      Jump Shot       2       BRO  388.0  10:39  2017-04-12
# 7140       CHI      Jump Shot       3       BRO  401.0  11:10  2017-04-12
# 7141       CHI      Jump Shot       3       BRO  128.0  11:32  2017-04-12
#
#                shooter  time from last shot  quarter current_shot_outcome  \
# 0          Dwyane Wade                  NaN        1               SCORED
# 1           Taj Gibson                 51.0        1               MISSED
# 2          Rajon Rondo                  7.0        1               MISSED
# 3          Robin Lopez                 12.0        1               MISSED
# 4          Dwyane Wade                 30.0        1               MISSED
# ...                ...                  ...      ...                  ...
# 7137  Denzel Valentine                 27.0        4               SCORED
# 7138  Denzel Valentine                 31.0        4               MISSED
# 7139    Anthony Morrow                 26.0        4               SCORED
# 7140      Bobby Portis                 31.0        4               SCORED
# 7141  Denzel Valentine                 22.0        4               MISSED
#
#       distance_from_half
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ...                  ...
# 7137               340.0
# 7138               410.0
# 7139               756.0
# 7140               442.0
# 7141               382.0
#
# [7142 rows x 17 columns]

# %%
full_df.to_json('halfcourt2.json')

# %%
sns.set_style("white")
sns.set_color_codes()
plt.figure(figsize=(12,11))
plt.scatter(full_df.LOC_X, full_df.LOC_Y)
plt.axis([-100, 600, 0, 500])
plt.show()

# %%
from matplotlib.patches import Circle, Rectangle, Arc

def draw_court(ax=None, color='black', lw=2, outer_lines=False):
    # If an axes object isn't provided to plot onto, just get current one
    if ax is None:
        ax = plt.gca()

    # Create the various parts of an NBA basketball court

    # Create the basketball hoop
    # Diameter of a hoop is 18" so it has a radius of 9", which is a value
    # 7.5 in our coordinate system
    hoop = Circle((250, 50), radius=7.5, linewidth=lw, color=color, fill=False)

    # Create backboard
    backboard = Rectangle((220, 42.5), 60, -1, linewidth=lw, color=color)

    # The paint
    # Create the outer box 0f the paint, width=16ft, height=19ft
    outer_box = Rectangle((170, 3.5), 160, 190, linewidth=lw, color=color,
                          fill=False)
    # Create the inner box of the paint, widt=12ft, height=19ft
    inner_box = Rectangle((190, 3.5), 120, 190, linewidth=lw, color=color,
                          fill=False)

    # Create free throw top arc
    top_free_throw = Arc((250, 192.5), 120, 120, theta1=0, theta2=180,
                         linewidth=lw, color=color, fill=False)
    # Create free throw bottom arc
    bottom_free_throw = Arc((250, 192.5), 120, 120, theta1=180, theta2=0,
                            linewidth=lw, color=color, linestyle='dashed')
    # Restricted Zone, it is an arc with 4ft radius from center of the hoop
    restricted = Arc((250, 50), 80, 80, theta1=0, theta2=180, linewidth=lw,
                     color=color)

    # Three point line
    # Create the side 3pt lines, they are 14ft long before they begin to arc
    corner_three_a = Rectangle((30, 3.5), 0, 140, linewidth=lw,
                               color=color)
    corner_three_b = Rectangle((470, 3.5), 0, 140, linewidth=lw, color=color)
    # 3pt arc - center of arc will be the hoop, arc is 23'9" away from hoop
    # I just played around with the theta values until they lined up with the 
    # threes
    three_arc = Arc((250, 50), 475, 475, theta1=22, theta2=158, linewidth=lw,
                    color=color)

    # Center Court
    center_outer_arc = Arc((250, 470), 120, 120, theta1=180, theta2=0,
                           linewidth=lw, color=color)
    center_inner_arc = Arc((250, 470), 40, 40, theta1=180, theta2=0,
                           linewidth=lw, color=color)

    # List of the court elements to be plotted onto the axes
    court_elements = [hoop, backboard, outer_box, inner_box, top_free_throw,
                      bottom_free_throw, restricted, corner_three_a,
                      corner_three_b, three_arc, center_outer_arc,
                      center_inner_arc]

    if outer_lines:
        # Draw the half court line, baseline and side out bound lines
        outer_lines = Rectangle((0, 3.5), 500, 470, linewidth=lw,
                                color=color, fill=False)
        court_elements.append(outer_lines)

    # Add the court elements onto the axes
    for element in court_elements:
        ax.add_patch(element)

    return ax

# %%
plt.figure(figsize=(12,11))
draw_court(outer_lines=True)
plt.xlim(-100,600)
plt.ylim(-100,500)
plt.show()

# %%
color_dict = dict({'MISSED': 'blue',
                  'SCORED': 'red',
                  'BLOCKED': 'green'})

# %%
plt.figure(figsize=(12,11))
plt.scatter(full_df.LOC_X, full_df.LOC_Y)
draw_court(outer_lines=True)
# Descending values along the axis from left to right
plt.xlim(-50,550)
plt.ylim(-50,525)

# plt.xlim(-50,550)
# plt.ylim(-50,940)
plt.show()

# %%
color_dict = dict({'MISSED': 'blue',
                  'SCORED': 'red',
                  'BLOCKED': 'green'})

plt.figure(figsize=(12,11))
sns.scatterplot(x="LOC_X", y="LOC_Y", hue="current_shot_outcome",
              data=full_df, palette=color_dict, 
                   legend='full')

draw_court(outer_lines=True)
# Descending values along the axis from left to right
plt.xlim(-50,550)
plt.ylim(-50,525)
plt.show()

# %%
jb = full_df[full_df.shooter == "Jimmy Butler"]

color_dict = dict({'MISSED': 'blue',
                  'SCORED': 'red',
                  'BLOCKED': 'green'})

plt.figure(figsize=(12,11))
sns.scatterplot(x="LOC_X", y="LOC_Y", hue="current_shot_outcome",
              data=jb, palette=color_dict, 
                   legend='full')
draw_court(outer_lines=True)
# Descending values along the axis from left to right
plt.xlim(-50,550)
plt.ylim(-50,525)

plt.savefig('jimmy.png')
plt.show()

# %%
rr = full_df[full_df.shooter == "Rajon Rondo"]

color_dict = dict({'MISSED': 'blue',
                  'SCORED': 'red',
                  'BLOCKED': 'green'})

plt.figure(figsize=(12,11))
sns.scatterplot(x="LOC_X", y="LOC_Y", hue="current_shot_outcome",
              data=rr, palette=color_dict, 
                   legend='full')
draw_court(outer_lines=True)
# Descending values along the axis from left to right
plt.xlim(-50,550)
plt.ylim(-50,525)


plt.savefig('rondo.png')

plt.show()

# %%
tg = full_df[full_df.shooter == "Taj Gibson"]

color_dict = dict({'MISSED': 'blue',
                  'SCORED': 'red',
                  'BLOCKED': 'green'})

plt.figure(figsize=(12,11))
sns.scatterplot(x="LOC_X", y="LOC_Y", hue="current_shot_outcome",
              data=tg, palette=color_dict, 
                   legend='full')
draw_court(outer_lines=True)
# Descending values along the axis from left to right
plt.xlim(-50,550)
plt.ylim(-50,525)

plt.savefig('Taj_Gibson.png')
plt.show()

# %%
dw = full_df[full_df.shooter == "Dwyane Wade"]

color_dict = dict({'MISSED': 'blue',
                  'SCORED': 'red',
                  'BLOCKED': 'green'})

plt.figure(figsize=(12,11))
sns.scatterplot(x="LOC_X", y="LOC_Y", hue="current_shot_outcome",
              data=dw, palette=color_dict, 
                   legend='full')
draw_court(outer_lines=True)
# Descending values along the axis from left to right
plt.xlim(-50,550)
plt.ylim(-50,525)

plt.savefig('Dwyane Wade.png')
plt.show()

# %%
rl = full_df[full_df.shooter == "Robin Lopez"]

color_dict = dict({'MISSED': 'blue',
                  'SCORED': 'red',
                  'BLOCKED': 'green'})

plt.figure(figsize=(12,11))
sns.scatterplot(x="LOC_X", y="LOC_Y", hue="current_shot_outcome",
              data=rl, palette=color_dict, 
                   legend='full')
draw_court(outer_lines=True)
# Descending values along the axis from left to right
plt.xlim(-50,550)
plt.ylim(-50,525)

plt.savefig('Robin_Lopez.png')
plt.show()

# %%
nm = full_df[full_df.shooter == "Nikola Mirotic"]

color_dict = dict({'MISSED': 'blue',
                  'SCORED': 'red',
                  'BLOCKED': 'green'})

plt.figure(figsize=(12,11))
sns.scatterplot(x="LOC_X", y="LOC_Y", hue="current_shot_outcome",
              data=nm, palette=color_dict, 
                   legend='full')
draw_court(outer_lines=True)
# Descending values along the axis from left to right
plt.xlim(-50,550)
plt.ylim(-50,525)


plt.savefig('Nikola_Mirotic.png')
plt.show()
