# %%
import pandas as pd

# %%
nba_shots_2018="playoff_shots.csv"

# %%
pd.read_csv(nba_shots_2018)
# Out:
#                GRID_TYPE   GAME_ID  GAME_EVENT_ID  PLAYER_ID  \
# 0      Shot Chart Detail  41700131            149       2544
# 1      Shot Chart Detail  41700131            153       2544
# 2      Shot Chart Detail  41700131            155       2544
# 3      Shot Chart Detail  41700131            187       2544
# 4      Shot Chart Detail  41700131            195       2544
# ...                  ...       ...            ...        ...
# 13465  Shot Chart Detail  41700123            736     202337
# 13466  Shot Chart Detail  41700101            189     204025
# 13467  Shot Chart Detail  41700163            598       2731
# 13468  Shot Chart Detail  41700211            652    1626158
# 13469  Shot Chart Detail  41700144            642    1627875
#
#                PLAYER_NAME     TEAM_ID               TEAM_NAME  PERIOD  \
# 0             LeBron James  1610612739     Cleveland Cavaliers       1
# 1             LeBron James  1610612739     Cleveland Cavaliers       1
# ...
